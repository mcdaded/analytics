# %% [markdown]
# Based on example from <a>https://towardsdatascience.com/an-introduction-to-bayesian-inference-in-pystan-c27078e58d53</a>

# %%
import pystan
import pandas as pd
import numpy as np

from IPython.core.pylabtools import figsize
from matplotlib import pyplot as pltx
import seaborn as sns
sns.set(style="ticks")
# %matplotlib inline
figsize(16, 6)

from sklearn.metrics import r2_score

sns.set()  # Nice plot aesthetic
np.random.seed(101)

# %%
def plot_trace(param, param_name='parameter'):
    """Plot the trace and posterior of a parameter."""

    # Summary statistics
    mean = np.mean(param)
    median = np.median(param)
    cred_min, cred_max = np.percentile(param, 2.5), np.percentile(param, 97.5)

    # Plotting
    plt.subplot(2,1,1)
    plt.plot(param)
    plt.xlabel('samples')
    plt.ylabel(param_name)
    plt.axhline(mean, color='r', lw=2, linestyle='--')
    plt.axhline(median, color='c', lw=2, linestyle='--')
    plt.axhline(cred_min, linestyle=':', color='k', alpha=0.2)
    plt.axhline(cred_max, linestyle=':', color='k', alpha=0.2)
    plt.title('Trace and Posterior Distribution for {}'.format(param_name))

    plt.subplot(2,1,2)
    plt.hist(param, 30, density=True); sns.kdeplot(param, shade=True)
    plt.xlabel(param_name)
    plt.ylabel('density')
    plt.axvline(mean, color='r', lw=2, linestyle='--',label='mean')
    plt.axvline(median, color='c', lw=2, linestyle='--',label='median')
    plt.axvline(cred_min, linestyle=':', color='k', alpha=0.2, label='95% CI')
    plt.axvline(cred_max, linestyle=':', color='k', alpha=0.2)

    plt.gcf().tight_layout()
    plt.legend()

# %% [markdown]
# ## Create a simple linear model for the data

# %%
model = """
data {
    int<lower=0> N;
    vector[N] x;
    vector[N] y;
}
parameters {
    real alpha;
    real beta;
    real<lower=0> sigma;
}
model {
    y ~ normal(alpha + beta * x, sigma);
}
"""

# %%
# Parameters to be inferred
alpha = 4.0
beta = 0.5
sigma = 1.0

# Generate and plot data
x = 10 * np.random.rand(100)
y = alpha + beta * x
y = np.random.normal(y, scale=sigma)

# %%
# Put our data in a dictionary
data = {'N': len(x), 'x': x, 'y': y}

# Compile the model
sm1 = pystan.StanModel(model_code=model)

# Train the model and generate samples
fit1 = sm1.sampling(data=data, iter=1000, chains=4, warmup=500, thin=1, seed=101)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_cb4cc9c2a04d0e34d711077557307fb7 NOW.
# /home/dan/.pyenv/versions/miniconda3-4.3.30/envs/bayes/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmplpxmiaqg/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_8452444779766283972.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
summary_dict = fit1.summary()
df = pd.DataFrame(summary_dict['summary'], 
                  columns=summary_dict['summary_colnames'], 
                  index=summary_dict['summary_rownames'])

alpha_mean, beta_mean = df['mean']['alpha'], df['mean']['beta']

# Extracting traces
alpha = fit['alpha']
beta = fit['beta']
sigma = fit['sigma']
lp = fit['lp__']

df
# Out:
#               mean   se_mean        sd         2.5%          25%          50%  \
# alpha     1.005405  0.000143  0.004477     0.996762     1.002363     1.005348
# beta      1.994117  0.000247  0.007768     1.978456     1.988870     1.994188
# sigma     0.101504  0.000055  0.001602     0.098342     0.100374     0.101535
# lp__   3574.751251  0.042686  1.160465  3571.793923  3574.176016  3575.042305
#
#                75%        97.5%       n_eff      Rhat
# alpha     1.008297     1.014504  979.706763  0.999625
# beta      1.999429     2.008829  987.008896  1.000630
# sigma     0.102602     0.104569  848.944805  1.004452
# lp__   3575.612503  3576.126757  739.089581  1.006564

# %%
plot_trace(alpha)

# %%
plot_trace(beta)

# %%
predicted = df.loc['alpha', 'mean'] + df.loc['beta', 'mean'] * x
predicted
# Out:
# array([1.00540486, 1.00640242, 1.00739998, ..., 2.99752685, 2.99852441,
#        2.99952197])

# %%
r2_score(y, predicted)
# Out:
# 0.9699725554048962

# %% [markdown]
# ## Another sample

# %%
# https://docs.pymc.io/notebooks/GLM-linear.html
size = 2000
true_intercept = 1
true_slope = 2

x = np.linspace(0, 1, size)
# y = a + b*x
true_regression_line = true_intercept + true_slope * x
# add noise
y = true_regression_line + np.random.normal(scale=.1, size=size)

# %%
model = """
data {
    int<lower=0> N;
    vector[N] x;
    vector[N] y;
}
parameters {
    real alpha;
    real beta;
    real<lower=0> sigma;
}
model {
    y ~ normal(alpha + beta * x, sigma);
}
"""

# %%
# Put our data in a dictionary
data = {'N': len(x), 'x': x, 'y': y}

# Compile the model
sm2 = pystan.StanModel(model_code=model)

# Train the model and generate samples
fit2 = sm2.sampling(data=data, iter=1000, chains=4, warmup=500, thin=1, seed=101)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_cb4cc9c2a04d0e34d711077557307fb7 NOW.
# /home/dan/.pyenv/versions/miniconda3-4.3.30/envs/bayes/lib/python3.8/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/tmpbybqx3ox/stanfit4anon_model_cb4cc9c2a04d0e34d711077557307fb7_4795801171404549742.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
summary_dict = fit2.summary()
df = pd.DataFrame(summary_dict['summary'], 
                  columns=summary_dict['summary_colnames'], 
                  index=summary_dict['summary_rownames'])

alpha_mean, beta_mean = df['mean']['alpha'], df['mean']['beta']

# Extracting traces
alpha = fit['alpha']
beta = fit['beta']
sigma = fit['sigma']
lp = fit['lp__']

df
# Out:
#               mean   se_mean        sd         2.5%          25%          50%  \
# alpha     1.001167  0.000129  0.004503     0.992194     0.998160     1.001215
# beta      2.005240  0.000237  0.007871     1.989900     1.999809     2.005309
# sigma     0.104164  0.000048  0.001618     0.101065     0.103052     0.104154
# lp__   3522.910650  0.044251  1.163937  3520.079363  3522.337674  3523.209323
#
#                75%        97.5%        n_eff      Rhat
# alpha     1.004043     1.009848  1216.211374  1.001726
# beta      2.010531     2.020693  1107.284755  1.001535
# sigma     0.105216     0.107274  1130.276030  0.999025
# lp__   3523.801516  3524.283330   691.839552  1.009386

# %%
plot_trace(alpha)

# %%
plot_trace(beta)

# %%
predicted = df.loc['alpha', 'mean'] + df.loc['beta', 'mean'] * x
predicted
# Out:
# array([1.00116704, 1.00217016, 1.00317328, ..., 3.00440071, 3.00540383,
#        3.00640695])

# %%
r2_score(y, predicted)
# Out:
# 0.9687626532303225
